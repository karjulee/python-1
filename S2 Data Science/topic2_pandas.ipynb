# %%
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df2 = pd.read_csv("chemistry_quantom_dot_data_pandas.csv")
df2
# Out:
#      Wavelength (nm) Material Type Surface Ligand  Quantum Yield (%)  \
# 0              570.8          CdSe     Oleic acid               68.3
# 1              599.6           InP            MPA               51.9
# 2              569.6           InP            PEG               80.5
# 3              571.2          CdSe            PEG               71.5
# 4              575.5          CdSe     Oleic acid               97.0
# ..               ...           ...            ...                ...
# 495            529.8          CdSe     Oleic acid               69.2
# 496            607.2          CdSe            PEG               50.6
# 497            562.3          CdSe           TOPO               72.2
# 498            565.9           InP            MPA               81.6
# 499            576.4          CdSe     Oleic acid               71.0
#
#      Particle Size (nm)
# 0                  4.04
# 1                  3.76
# 2                  3.33
# 3                  4.03
# ...

# %%
df2.describe()
# Out:
#        Wavelength (nm)  Quantum Yield (%)  Particle Size (nm)
# count       500.000000         500.000000           500.00000
# mean        688.597600          63.389200             3.82234
# std         262.189774          16.022576             1.02709
# min         507.000000          15.000000             2.00000
# 25%         554.000000          53.250000             3.10000
# 50%         574.100000          63.700000             3.66500
# 75%         603.125000          75.500000             4.35000
# max        1572.400000          97.000000             7.77000

# %%
df2.plot()
# Out:
# <Axes: >

# %%
# i am interested in watchign average of wavelength based on surface
# collect data1 = df2[['column1','column2']]
# dataframe.grouby(surface_column).mean()

# %%
data1 = df2[['Wavelength (nm)','Surface Ligand']]
data1.groupby('Surface Ligand').mean()
# Out:
#                 Wavelength (nm)
# Surface Ligand
# MPA                  655.817857
# Oleic acid           704.144541
# PEG                  663.007071
# TOPO                 708.219318

# %%
data2 = df2[['Wavelength (nm)','Material Type']]
data2.groupby('Material Type').mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Material Type'>

# %%
# groupby based on surface and material type find average of all

# %%
gb_df = df2.groupby(['Material Type','Surface Ligand']).mean()
gb_df[['Quantum Yield (%)',	'Particle Size (nm)']]
# Out:
#                               Quantum Yield (%)  Particle Size (nm)
# Material Type Surface Ligand
# CdSe          MPA                     69.924000            3.412800
#               Oleic acid              73.363000            3.833300
#               PEG                     73.727586            3.816897
#               TOPO                    78.364706            3.767647
# InP           MPA                     51.022917            3.103125
#               Oleic acid              59.074390            3.240976
#               PEG                     63.250909            3.084727
# PbS           MPA                     42.827273            5.785455
#               Oleic acid              49.523404            5.309787
#               PEG                     47.166667            5.135333
#               TOPO                    43.255000            5.051500

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Material Type',y='Quantum Yield (%)',data =df2)
# Out:
# <Axes: xlabel='Material Type', ylabel='Quantum Yield (%)'>

# %%
sns.barplot(x='Material Type',y='Quantum Yield (%)',data =df2)
# Out:
# <Axes: xlabel='Material Type', ylabel='Quantum Yield (%)'>

# %%
sns.violinplot(x='Material Type',y='Quantum Yield (%)',data =df2)
# Out:
# <Axes: xlabel='Material Type', ylabel='Quantum Yield (%)'>

# %%
# lets see Quantum Yield (%)	Particle Size (nm) with respect to material type
sns.scatterplot(x='Particle Size (nm)',y='Quantum Yield (%)',data =df2,hue="Material Type")
# Out:
# <Axes: xlabel='Particle Size (nm)', ylabel='Quantum Yield (%)'>

# %%
# can you do it same for surface type
sns.scatterplot(x='Particle Size (nm)',y='Quantum Yield (%)',data =df2,hue="Surface Ligand")
# Out:
# <Axes: xlabel='Particle Size (nm)', ylabel='Quantum Yield (%)'>

# %%
sns.pairplot(df2,hue="Surface Ligand")
