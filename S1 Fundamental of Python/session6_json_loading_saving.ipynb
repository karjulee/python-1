# %%
data = {'H20':
            {   'name':'water',
                "composition":["Hydrogen","Oxygen"]
             }
        
        }

# %%
import json

# %%
file = open("chemistry.json")
data = json.load(file)
print(data)
# Out:
# {'H2O': {'name': 'Water', 'weight': 18.02, 'state': 'Liquid', 'uses': ['Drinking', 'Cooling']}, 'C6H12O6': {'name': 'Glucose', 'weight': 180.16, 'state': 'Solid', 'uses': ['Energy', 'Respiration']}, 'NaCl': {'name': 'Salt', 'weight': 58.44, 'state': 'Solid', 'uses': ['Seasoning', 'Preservative']}}

# %%
## so we have to print all data in proper format

# %%
for abc in data:
    print(f"the formula is {abc}")
    for xyz in data[abc]:
        print(f"{xyz} have value {data[abc][xyz]}")
# Out:
# the formula is H2O
# name have value Water
# weight have value 18.02
# state have value Liquid
# uses have value ['Drinking', 'Cooling']
# the formula is C6H12O6
# name have value Glucose
# weight have value 180.16
# state have value Solid
# uses have value ['Energy', 'Respiration']
# the formula is NaCl
# name have value Salt
# weight have value 58.44
# state have value Solid
# uses have value ['Seasoning', 'Preservative']

# %%
for
