# %%
# to add 3 numbers

# %%
a = 10
b = 20 
c = 30
print(a+b+c)
print(a*b*c)
# Out:
# 60
# 6000

# %%
a = 100
b = 200 
c = 300
print(a+b+c)
print(a*b*c)
# Out:
# 600
# 6000000

# %%
# we can make method to print or return the output

# %%
def mysum(x,y,z):
    print(x+y+z,'sum')
    print(x*y*z,'prod')

# %%
mysum(10,20,30)
mysum(100,200,300)
# Out:
# 60 sum
# 6000 prod
# 600 sum
# 6000000 prod

# %%
# make a function  that takes name and country and print it like karju is from thiland

# %%
def name_country(n,c,key='',model=''):
    print(n,c)
    print("key is ",key,'value is ',model)
    return n+c+key

# %%
cleint1 = name_country('karju','thailand','sk12312312')
# Out:
# karju thailand
# key is  sk12312312 value is

# %%
name_country(c='pakistan',n='umair',model='google')
# Out:
# umair pakistan
# key is   value is  google
# 'umairpakistan'

# %%
cleint1
# Out:
# 'karjuthailandsk12312312'

# %%
def maker(what='sum'):
    if what =="sum":
        return sum
    if what=="maxn":
        return max

# %%
cleint = maker("sum")

# %%
cleint([1,2,3])
# Out:
# 6

# %%
from funAI import fun
# from module import function/class

# %%
fun()
# Out:
# 'hello'

# %%
pip install openai
# Out:
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 44.9 kB/s  0:00:18 eta 0:00:05
# ...
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# ...
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#   WARNING: The script tqdm is installed in '/Library/Frameworks/Python.framework/Versions/3.13/bin' which is not on PATH.
# ...

# %%
from openai import OpenAI

jumodel="google/gemini-2.0-flash-exp:free"
api_key = "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"

# %%
client = OpenAI(
    # Or use the `OPENAI_BASE_URL` env var
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1",
)

# %%
cleint2 = OpenAI(api_key="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",
    base_url="https://openrouter.ai/api/v1",)

# %%
result = cleint2.completions.create(
    model=jumodel,
    prompt="helloo how are you waht is your name"
    
)

# %%
outresult.choices[0].text.strip()
# Out:
# "Hello! I'm doing well, thank you for asking. I don't have a name - I am a large language model, an AI assistant. You can just call me AI if you like! How can I help you today?"

# %%
'       apple           '.strip()
# Out:
# 'apple'

# %%
while True:
    msg = input("please enter your msg")
    
    result = cleint2.completions.create(
    model=jumodel,
    prompt=msg
    )
    

    print(result.choices[0].text.strip())
# Out:
# Math, short for mathematics, is a vast and interconnected field of study that deals with:
#
# *   **Numbers:** Exploring their properties, relationships, and operations (addition, subtraction, multiplication, division, etc.).
# *   **Quantities:** Measuring and comparing amounts.
# *   **Shapes:** Analyzing their forms, sizes, and spatial relationships (geometry).
# *   **Structures:** Identifying patterns, organizing data, and building logical systems (algebra, topology).
# *   **Change:** Modeling motion, growth, and other dynamic processes (calculus).
# *   **Logic:** Reasoning, proving theorems, and constructing arguments.
# *   **Patterns:** Recognizing and generalizing regularities.
#
# Think of it as:
#
# *   **A language:**  With its own symbols, grammar, and vocabulary, used to describe and analyze the world around us.
# *   **A tool:**  For solving problems in science, engineering, economics, computer science, and many other fields.
# ...

# %%
import time
def get_ai_answer(msg):
    try:
        result = cleint2.completions.create(
        model=jumodel,
        prompt=msg
        )
    except:
        return("did not work wait for 1 second ")
        time.sleep(1)
    

    return (result.choices[0].text.strip())

# %%
get_ai_answer('what is date today' )
# Out:
# 'Today is Sunday, May 12th, 2024.'

# %%
get_ai_answer("what is time now")
# Out:
# 'Right now, it is 4:43 PM Pacific Time (PDT).'

# %%
get_ai_answer("how many main topics in python")
# Out:
# 'Python is a vast language with many aspects, but we can break down the main topics into several core areas. Here\'s a breakdown of the major topic areas in Python, along with a brief description of each:\n\n**1. Basic Syntax and Data Types:**  This is the foundation of any Python programming.\n   *   **Variables:** How to store and name data.\n   *   **Data Types:**  Understanding different types of data (integers, floats, strings, booleans, lists, tuples, dictionaries, sets).  This is extremely important because the type of data influences what operations you can do with it.\n   *   **Operators:** Arithmetic, comparison, logical operators, assignment operators.\n   *   **Input/Output:**  How to get data from the user (input()) and display results (print()).\n\n**2. Control Flow:**  Controls the execution of your code based on conditions.\n   *   **Conditional Statements:** `if`, `elif`, `else`  (execute different code blocks based on conditions).\n   *   **Loops:**  `for` (iterate 
# ...

# %%
def add(a,b,*c,**d):
    print(a)
    print(b)
    print(c)
    print(d)

# %%
add(1,2,3,4,5,6,p=100,k = 200)
# Out:
# 1
# 2
# (3, 4, 5, 6)
# {'p': 100, 'k': 200}
