# %%
name = "Mena"
country = "Thailand"

# %%
print(name)
# Out:
# Mena

# %%
print(country)
# Out:
# Thailand

# %%
print(f'name is {name} and country is {country}')
# Out:
# name is Mena and country is Thailand

# %%
name = "Alia"
age = 30
height = 10.5
print(f"name is {name}, age is {age}, height is {height}")
# Out:
# name is Alia, age is 30, height is 10.5

# %%
## next time 
temp = 51
if temp >50:
    print('turn off burner')
# Out:
# turn off burner

# %%
name = "Ju"

# %%
print(f'Hello, my name is {name}')
# Out:
# Hello, my name is Ju

# %%
n = 5
n2 = 7
print(f'The sum of 5 and 7 is {n+n2}')
# Out:
# The sum of 5 and 7 is 12

# %%
name = 'Apple' 
price = 50
print(f'The price of {name} is {price} rupees')
# Out:
# The price of Apple is 50 rupees

# %%
age = 27
if age > 18:
    print('You are an adult')
else:
    print('You are not an adult')
# Out:
# You are an adult
