# %% [markdown]
# <h1> This is a data types </h1>

# %%
print('hello')
# Out:
# hello

# %%
name = ""

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.1 MB 8.6 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.1 MB 8.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 9.0 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------------- -- 2.1/2.3 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 10.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.0 MB 11.6 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.0 MB 13.5 MB/s eta 0:00:01
# ...

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.8 MB 10.8 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.8 MB 12.3 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.8 MB 13.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.8 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 13.9 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
t = np.linspace(0,20,400)
A_t = 5 * np.exp(2*t)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t,A_t)
